# %% [markdown]
# <a href="https://colab.research.google.com/github/hariprasad2422/FMML_LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 07:34:13--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   303MB/s    in 0.2s
#
# 2024-03-27 07:34:18 (303 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12857  1711.09404v1  Deep neural networks have proven remarkably ef...    cs
# 10419   1306.6482v1  We consider the traffic data reconstruction pr...  stat
# 19723   1109.6841v1  Suppose we want to build a system that answers...    cs
# 659    1608.04374v2  In this paper, a geometric framework for neura...  stat
# 18548   1105.5459v1  A previously developed quantum search algorith...    cs
# ...             ...                                                ...   ...
# 12375  1712.09043v2  In recent years, deep neural networks have yie...    cs
# 40492   1204.0170v2  Latent Dirichlet allocation (LDA) is a widely-...    cs
# 22384  1605.03267v2  We present a new method for estimating multiva...  stat
# 9668   1605.01643v1  Any closed, connected Riemannian manifold $M$ ...  stat
# 17420  1711.01006v1  While neural machine translation (NMT) has bec...    cs
#
#                                                    title  year  \
# 12857  Improving the Adversarial Robustness and Inter...  2017
# 10419  Traffic data reconstruction based on Markov ra...  2013
# 19723  Learning Dependency-Based Compositional Semantics  2011
# 659    A Geometric Framework for Convolutional Neural...  2016
# 18548  Solving Highly Constrained Search Problems wit...  2011
# ...                                                  ...   ...
# 12375  Collaborative Autoencoder for Recommender Systems  2017
# 40492       A New Approach to Speeding Up Topic Modeling  2012
# 22384  Generalized Sparse Precision Matrix Selection ...  2016
# 9668   The embedding dimension of Laplacian eigenfunc...  2016
# 17420  Towards Neural Machine Translation with Partia...  2017
#
#                                                 keywords
# 12857  [remarkably, effective, classification, critic...
# 10419  [reconstruction, incomplete, unobserved, recon...
# 19723  [representing, semantics, computing, structure...
# 659    [geometric, framework, framework, structure, u...
# 18548  [previously, developed, algorithm, generalized...
# ...                                                  ...
# 12375  [performance, combining, recommendation, highl...
# 40492  [dirichlet, allocation, probabilistic, applica...
# 22384  [estimating, multivariate, stationary, precisi...
# 9668   [connected, riemannian, laplacian, eigenfuncti...
# 17420  [translation, parameter, optimization, transla...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12857    [remarkably, effective, classification, critic...
# 10419    [reconstruction, incomplete, unobserved, recon...
# 19723    [representing, semantics, computing, structure...
# 659      [geometric, framework, framework, structure, u...
# 18548    [previously, developed, algorithm, generalized...
#                                ...
# 11952    [fundamental, importance, algorithms, obtainin...
# 6712     [computational, differences, reference, minimi...
# 9627     [generalized, likelihood, coefficients, conven...
# 27843    [automatically, generating, descriptions, appr...
# 4313     [randomized, principal, component, employing, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8841 words.
# Out of those 4604 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9b496c97-eb2b-43a3-8db6-a43022a685b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b496c97-eb2b-43a3-8db6-a43022a685b5")) {                    Plotly.newPlot(                        "9b496c97-eb2b-43a3-8db6-a43022a685b5",                        [{"x":["themselves","effective","improving","legitimate","transparency","regularization","gradients","effectiveness","uninterpretable","remarkably","architectures","relationship","obstacles","regularized","perturbations","demonstrate","generated","discussing","predictions","weaknesses","naturally","interpretable","robustness","classification","transferred","regularizing","rationales","adversarial","interpretability","criticized","misclassifications","unobserved","collected","incomplete","realistic","reconstruct","numerically","performance","simulated","reconstruction","procedure","benchmarks","alternates","parameters","semantics","expensive","favorable","formalism","numerical","dependency","distribution","questions","challenging","annotation","statistical","linguistic","typically","computing","optimization","motivated","outperforms","computational","compositional","representing","properties","annotated","structured","underlying","coordinate","functions","geometric","parameter","convolutional","structure","described","calculated","framework","component","structures","guarantee","classical","generalized","exponential","constrained","algorithms","algorithm","variables","previously","contrasts","developed","solutions","increases","computers","satisfiability","alternative","competitive","facilitate","simplicity","approximate","challenge","dependence","inference","predictors","connected","computationally","efficient","difficulty","interacting","intractable","penalizes","optimized","regularizer","prediction","predictive","informative","conceptual","essentially","regression","increased","categorical","fundamental","recursive","producing","categories","overfitting","performing","splitting","important","ubiquitous","consequence","selecting","contribute","selection","manifests","validation","validated","partitioning","extensive","importantly","inability","approaches","significantly","reasonable","precludes","complexity","different","replacing","following","assumptions","simulation","particular","propagation","explanation","relevance","interpret","deconvolution","evaluating","arguments","usefulness","individual","investigate","understand","collections","implications","impressive","demonstrated","objective","sensitivity","quantitatively","reasoning","practical","assessment","importance","theoretical","perturbation","nonlinear","qualitatively","visualization","unsupervised","transparent","recognition","methodology","inferring","independently","sufficiently","asymmetry","dimensional","dimensionality","experiments","applicable","covariance","observations","relations","deterministic","stochastic","distributions","modification","collective","processes","autoencoders"],"y":[26,254,99,2,9,84,21,191,2,12,130,88,12,44,10,539,188,13,79,8,56,33,102,498,17,6,3,95,16,2,2,5,62,36,55,25,8,877,53,92,114,104,6,238,106,63,16,18,85,47,200,78,262,68,171,66,109,146,340,59,282,282,30,68,215,82,109,121,20,224,56,113,362,341,55,25,537,90,111,36,82,76,38,64,595,826,131,94,6,202,155,38,33,13,76,103,42,23,92,138,22,187,15,62,90,408,47,11,28,3,64,17,222,62,43,26,24,121,38,14,84,19,17,90,26,77,11,325,17,14,39,30,172,0,54,35,15,184,38,1,405,267,28,1,235,758,12,81,61,68,260,69,22,46,23,12,71,22,28,132,155,72,27,28,26,100,184,41,28,122,136,47,103,180,10,61,27,20,150,7,385,70,30,33,18,1,178,37,563,54,32,62,98,37,118,108,25,14,101,13],"type":"bar"},{"x":["themselves","effective","improving","legitimate","transparency","r ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4604,), (4604, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style=''>Regenerative</span> <span style=''>Learning</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hierarchical</span> <span style=''>Features</span> <span style=''>in</span> <span style=''>Spiking</span> <span style=''>Deep</span> <span style=''>Networks</span> <span style=''>for</span> <span style=''>Object</span> <span style='background-color:rgba(0, 255, 0, 0.6244725738396625);'>Recognition</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>spike</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>regenerative</span> <span style=''>learning</span> <span style=''>scheme</span> <span style=''>to</span> <span style=''>train</span> <span style=''>Spiking</span> <span style=''>Deep</span> <span style=''>Networks</span> <span style=''>(SpikeCNN)</span> <span style=''>for</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.6244725738396625);'>recognition</span> <span style=''>problems</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biologically</span> <span style='background-color:rgba(0, 255, 0, 0.34146341463414637);'>realistic</span> <span style=''>leaky</span> <span style='background-color:rgba(0, 255, 0, 0.30555555555555547);'>integrate</span> <span style=''>and</span> <span style=''>fire</span> <span style=''>neurons</span> <span style=''>The</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Auto</span> <span style=''>Encoder</span> <span style=''>learning</span> <span style=''>model</span> <span style=''>wherein</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style=''>network</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>layer</span> <span style=''>wise</span> <span style=''>using</span> <span style=''>the</span> <span style=''>encoder</span> <span style=''>decoder</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>Regenerative</span> <span style=''>learning</span> <span style=''>uses</span> <span style=''>spike</span> <span style=''>timing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>and</span> <span style=''>inherent</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>latencies</span> <span style=''>to</span> <span style=''>update</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>and</span> <span style=''>learn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representative</span> <span style=''>levels</span> <span style=''>for</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.6124721603563474);'>convolutional</span> <span style=''>layer</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>manner</span> <span style=''>The</span> <span style=''>features</span> <span style=''>learnt</span> <span style=''>from</span> <span style=''>the</span> <span style=''>final</span> <span style=''>layer</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchy</span> <span style=''>are</span> <span style=''>then</span> <span style=''>fed</span> <span style=''>to</span> <span style=''>an</span> <span style=''>output</span> <span style=''>layer</span> <span style=''>The</span> <span style=''>output</span> <span style=''>layer</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>with</span> <span style='background-c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>Lower</span> <span style=''>Bounds</span> <span style=''>for</span> <span style=''>Regret</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reinforcement</span> <span style=''>Learning</span> <br/><br/><span style=''>This</span> <span style=''>is</span> <span style=''>a</span> <span style=''>brief</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technical</span> <span style=''>note</span> <span style=''>to</span> <span style=''>clarify</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>regret</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>this</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reproduces</span> <span style=''>a</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>regret</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>similar</span> <span style=''>to</span> <span style=''>the</span> <span style=''>result</span> <span style=''>of</span> <span style=''>Theorem</span> <span style=''>5</span> <span style=''>in</span> <span style=''>the</span> <span style=''>journal</span> <span style=''>UCRL2</span> <span style=''>paper</span> <span style=''>(Jaksch</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2010)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clarifies</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>proof</span> <span style=''>of</span> <span style=''>Theorem</span> <span style=''>6</span> <span style=''>in</span> <span style=''>the</span> <span style=''>REGAL</span> <span style=''>paper</span> <span style=''>(Bartlett</span> <span style=''>and</span> <span style=''>Tewari</span> <span style=''>2009)</span> <span style=''>does</span> <span style=''>not</span> <span style=''>hold</span> <span style=''>using</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>without</span> <span style=''>further</span> <span style=''>work</span> <span style=''>We</span> <span style=''>suggest</span> <span style=''>that</span> <span style=''>this</span> <span style=''>result</span> <span style=''>should</span> <span style=''>instead</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conjecture</span> <span style=''>as</span> <span style=''>it</span> <span style=''>has</span> <span style=''>no</span> <span style=''>rigorous</span> <span style=''>proof</span> <span style=''>Suggests</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conjectured</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>given</span> <span style=''>by</span> <span style=''>(Bartlett</span> <span style=''>and</span> <span style=''>Tewari</span> <span style=''>2009)</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorrect</span> <span style=''>and</span> <span style=''>in</span> <span style=''>fact</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>the</span> <span style=''>scaling</span> <span style=''>of</span> <span style=''>the</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>to</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Solving</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3676731793960923);'>dimensional</span> <span style=''>committor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3089005235602094);'>artificial</span> <span style=''>neural</span> <span style=''>networks</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>note</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3089005235602094);'>artificial</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>to</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>between</span> <span style=''>states</span> <span style=''>governed</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3706666666666666);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>aim</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.38405797101449285);'>numerical</span> <span style=''>schemes</span> <span style=''>for</span> <span style=''>the</span> <span style=''>committor</span> <span style=''>function</span> <span style=''>the</span> <span style=''>central</span> <span style=''>object</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>path</span> <span style=''>theory</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satisfies</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3676731793960923);'>dimensional</span> <span style=''>Fokker</span> <span style=''>Planck</span> <span style=''>equation</span> <span style=''>By</span> <span style=''>working</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6331877729257642);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>such</span> <span style=''>partial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style=''>equation</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameterizing</span> <span style=''>the</span> <span style=''>committor</span> <span style=''>function</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3620689655172413);'>approximations</span> <span style=''>can</span> <span style=''>be</span> <span style=''>obtained</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>the</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>weights</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3706666666666666);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.38405797101449285);'>numerical</span> <span style=''>examples</span> <span style=''>show</span> <span style=''>that</span> <span style=''>moderate</span> <span style=''>accuracy</span> <span style=''>can</span> <span style=''>be</span> <span style=''>achieved</span> <span style=''>for</span> <span style=''>high</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Functional</span> <span style=''>Gradient</span> <span style=''>Boosting</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Residual</span> <span style=''>Network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Perception</span> <br/><br/><span style=''>Residual</span> <span style=''>Networks</span> <span style=''>(ResNets)</span> <span style=''>have</span> <span style=''>become</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>models</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>studies</span> <span style=''>have</span> <span style=''>been</span> <span style=''>devoted</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>why</span> <span style=''>ResNet</span> <span style=''>works</span> <span style=''>so</span> <span style=''>well</span> <span style=''>One</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attractive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>viewpoint</span> <span style=''>on</span> <span style=''>ResNet</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>the</span> <span style=''>risk</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>space</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>features</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>adopt</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>viewpoint</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>a</span> <span style=''>new</span> <span style=''>gradient</span> <span style=''>boosting</span> <span style=''>method</span> <span style=''>which</span> <span style=''>is</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style=''>very</span> <span style=''>powerful</span> <span style=''>in</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>To</span> <span style=''>do</span> <span style=''>so</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formalize</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>boosting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>of</span> <span style=''>ResNet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mathematically</span> <span style=''>using</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>called</span> <span style=''>ResFGB</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>ResNet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perception< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1279028224365845)
# 	representation (0.1293319042515184)
# 	automatic (0.07967131118256521)
# 	detection (0.10968202929617721)
# 	segmentation (0.0735977134690961)
# 	experimental (0.14040728831725616)
# 	information (0.24580207216863165)
# 	different (0.270811003929975)
# 	convolutional (0.1293319042515184)
# 	recognition (0.13754912468738836)
#
# Some Statistics words are:
# 	theoretical (0.1454272863568216)
# 	variables (0.13193403298350825)
# 	stochastic (0.12843578210894552)
# 	algorithm (0.3818090954522739)
# 	statistical (0.14992503748125938)
# 	estimation (0.16541729135432284)
# 	distribution (0.1874062968515742)
# 	dimensional (0.1924037981009495)
# 	regression (0.1744127936031984)
# 	inference (0.19940029985007496)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4125eae8-a571-42b5-9bdd-84eac0917abb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4125eae8-a571-42b5-9bdd-84eac0917abb")) {                    Plotly.newPlot(                        "4125eae8-a571-42b5-9bdd-84eac0917abb",                        [{"x":["themselves","effective","improving","legitimate","transparency","regularization","gradients","effectiveness","uninterpretable","remarkably","architectures","relationship","obstacles","regularized","perturbations","demonstrate","generated","discussing","predictions","weaknesses","naturally","interpretable","robustness","classification","transferred","regularizing","rationales","adversarial","interpretability","criticized","misclassifications","unobserved","collected","incomplete","realistic","reconstruct","numerically","performance","simulated","reconstruction","procedure","benchmarks","alternates","parameters","semantics","expensive","favorable","formalism","numerical","dependency","distribution","questions","challenging","annotation","statistical","linguistic","typically","computing","optimization","motivated","outperforms","computational","compositional","representing","properties","annotated","structured","underlying","coordinate","functions","geometric","parameter","convolutional","structure","described","calculated","framework","component","structures","guarantee","classical","generalized","exponential","constrained","algorithms","algorithm","variables","previously","contrasts","developed","solutions","increases","computers","satisfiability","alternative","competitive","facilitate","simplicity","approximate","challenge","dependence","inference","predictors","connected","computationally","efficient","difficulty","interacting","intractable","penalizes","optimized","regularizer","prediction","predictive","informative","conceptual","essentially","regression","increased","categorical","fundamental","recursive","producing","categories","overfitting","performing","splitting","important","ubiquitous","consequence","selecting","contribute","selection","manifests","validation","validated","partitioning","extensive","importantly","inability","approaches","significantly","reasonable","precludes","complexity","different","replacing","following","assumptions","simulation","particular","propagation","explanation","relevance","interpret","deconvolution","evaluating","arguments","usefulness","individual","investigate","understand","collections","implications","impressive","demonstrated","objective","sensitivity","quantitatively","reasoning","practical","assessment","importance","theoretical","perturbation","nonlinear","qualitatively","visualization","unsupervised","transparent","recognition","methodology","inferring","independently","sufficiently","asymmetry","dimensional","dimensionality","experiments","applicable","covariance","observations","relations","deterministic","stochastic","distributions","modification","collective","processes","autoencoders","autoencoder","techniques","capabilities","reduction","dimension","molecular","embeddings","contrasting","complementing","unlabeled","supervised","criterion","conventional","traditional","constraints","specifically","algorithmically","subproblem","abstraction","estimates","searching","hierarchy","descriptions","transformed","definition","heuristic","relaxation","interactive","generalization","committee","theoretically","empirically","structural","consistency","convergence","combination","accuracies","consideration","analogous","automated","conditional","exploration","weakening","literature","incoherence","considers","treatment","connections","minimization","improvement","tightening","constraint","accurately","recovered","elementa ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	manifests
# 	repeatmulti
# 	proprietary
# 	movielens
# 	distilling
# 	attributing
# 	frequentist
# 	pretreatment
# 	epidemiology
# 	robustification
# 	astronomical
# 	epanechnikov
# 	poisoning
# 	certifiable
# 	fmathcalx
# 	hoeffdings
# 	mcdiarmids
# 	particulars
# 	collinearity
# 	invertibility
# Some words which never appear in Statistics papers:
# 	obstacles
# 	rationales
# 	algorithmically
# 	weakening
# 	situational
# 	conversational
# 	surpassed
# 	occlusions
# 	reproduction
# 	supervisory
# 	formalisms
# 	nieuwenhuis
# 	propositional
# 	ecological
# 	insertion
# 	compositing
# 	unimodality
# 	colorization
# 	termination
# 	attribution

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0680493342332946e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
